# %% [markdown]
# <a href="https://colab.research.google.com/github/swopnimghimire-123123/data-analysis-visualization/blob/main/06_Pivot_Tables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###**Pivoit Tables**

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#          Date Product Region  Sales  Units    Rep
# 0  2023-01-01       A   East    402     10   John
# 1  2023-01-02       B   West    814     68   Mary
# 2  2023-01-03       C  North    183     70    Bob
# 3  2023-01-04       D  South    263     10  Alice
# 4  2023-01-05       A   East    194     92   John
# 5  2023-01-06       B   West    370     26   Mary
# 6  2023-01-07       C  North    977     21    Bob
# 7  2023-01-08       D  South    544     41  Alice
# 8  2023-01-09       A   East    125     18   John
# 9  2023-01-10       B   West    220     57   Mary
# 10 2023-01-11       C  North    351     80    Bob
# 11 2023-01-12       D  South    628     44  Alice
# 12 2023-01-13       A   East    953     23   John
# 13 2023-01-14       B   West    902     27   Mary
# 14 2023-01-15       C  North    191     56    Bob
# 15 2023-01-16       D  South    440     18  Alice
# 16 2023-01-17       A   East    651     49   John
# 17 2023-01-18       B   West    623     64   Mary
# 18 2023-01-19       C  North    311     42    Bob
# 19 2023-01-20       D  South    720     77  Alice

# %%
df["Month"] = df["Date"].dt.month_name()
df["Quarter"] = 'Q' + df["Date"].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    402     10   John  January      Q1
# 1  2023-01-02       B   West    814     68   Mary  January      Q1
# 2  2023-01-03       C  North    183     70    Bob  January      Q1
# 3  2023-01-04       D  South    263     10  Alice  January      Q1
# 4  2023-01-05       A   East    194     92   John  January      Q1
# 5  2023-01-06       B   West    370     26   Mary  January      Q1
# 6  2023-01-07       C  North    977     21    Bob  January      Q1
# 7  2023-01-08       D  South    544     41  Alice  January      Q1
# 8  2023-01-09       A   East    125     18   John  January      Q1
# 9  2023-01-10       B   West    220     57   Mary  January      Q1
# 10 2023-01-11       C  North    351     80    Bob  January      Q1
# 11 2023-01-12       D  South    628     44  Alice  January      Q1
# 12 2023-01-13       A   East    953     23   John  January      Q1
# 13 2023-01-14       B   West    902     27   Mary  January      Q1
# 14 2023-01-15       C  North    191     56    Bob  January      Q1
# 15 2023-01-16       D  South    440     18  Alice  January      Q1
# 16 2023-01-17       A   East    651     49   John  January      Q1
# 17 2023-01-18       B   West    623     64   Mary  January      Q1
# 18 2023-01-19       C  North    311     42    Bob  January      Q1
# 19 2023-01-20       D  South    720     77  Alice  January      Q1

# %%
pd.pivot_table(df,values = "Sales",index = 'Region',columns="Product",aggfunc = 'median')
# Out:
# Product      A      B      C      D
# Region
# East     402.0    NaN    NaN    NaN
# North      NaN    NaN  311.0    NaN
# South      NaN    NaN    NaN  544.0
# West       NaN  623.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     465.0    NaN    NaN    NaN  38.4   NaN   NaN   NaN
# North      NaN    NaN  402.6    NaN   NaN   NaN  53.8   NaN
# South      NaN    NaN    NaN  519.0   NaN   NaN   NaN  38.0
# West       NaN  585.8    NaN    NaN   NaN  48.4   NaN   NaN

# %% [markdown]
# ###**Cross Tabs**

# %%
pd.crosstab(df["Region"],df["Product"])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
